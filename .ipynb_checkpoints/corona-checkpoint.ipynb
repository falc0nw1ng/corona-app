# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import matplotlib.dates as mdates
sns.set()

df = pd.read_csv('https://query.data.world/s/ihom5k3szttx7w4w2wwqronax7k5db')

# %%
df.columns
# Out:
# Index(['Case_Type', 'Cases', 'Difference', 'Date', 'Country_Region',
#        'Province_State', 'Admin2', 'Combined_Key', 'FIPS', 'Lat', 'Long',
#        'Table_Names', 'Prep_Flow_Runtime'],
#       dtype='object')

# %%
df.head()
# Out:
#    Case_Type  Cases  Difference       Date Country_Region Province_State  \
# 0     Deaths      0         0.0  2/27/2020        Bahamas            NaN
# 1  Confirmed     16         0.0  2/16/2020        Germany            NaN
# 2     Deaths      0         0.0  1/31/2020         Canada        Alberta
# 3     Deaths      0         0.0   3/4/2020      Australia     Queensland
# 4  Confirmed      0         0.0  1/25/2020       Suriname            NaN
#
#   Admin2 Combined_Key  FIPS      Lat      Long  Table_Names  \
# 0    NaN          NaN   NaN  25.0343  -77.3963  Time Series
# 1    NaN          NaN   NaN  51.0000    9.0000  Time Series
# 2    NaN          NaN   NaN  53.9333 -116.5765  Time Series
# 3    NaN          NaN   NaN -28.0167  153.4000  Time Series
# 4    NaN          NaN   NaN   3.9193  -56.0278  Time Series
#
#       Prep_Flow_Runtime
# 0  4/6/2020 10:51:46 PM
# 1  4/6/2020 10:51:46 PM
# 2  4/6/2020 10:51:46 PM
# 3  4/6/2020 10:51:46 PM
# 4  4/6/2020 10:51:46 PM

# %%
canada_df = df[df['Country_Region'] == 'Canada']
canada_df.head()
# Out:
#     Case_Type  Cases  Difference       Date Country_Region  \
# 2      Deaths      0         0.0  1/31/2020         Canada
# 28     Deaths      0         0.0  3/14/2020         Canada
# 46     Deaths      1         1.0  3/20/2020         Canada
# 68  Confirmed      0         0.0  2/21/2020         Canada
# 73  Confirmed      2         1.0   3/7/2020         Canada
#
#           Province_State Admin2 Combined_Key  FIPS      Lat      Long  \
# 2                Alberta    NaN          NaN   NaN  53.9333 -116.5765
# 28  Prince Edward Island    NaN          NaN   NaN  46.5107  -63.4168
# 46               Alberta    NaN          NaN   NaN  53.9333 -116.5765
# 68               Alberta    NaN          NaN   NaN  53.9333 -116.5765
# 73               Alberta    NaN          NaN   NaN  53.9333 -116.5765
#
#     Table_Names     Prep_Flow_Runtime
# 2   Time Series  4/6/2020 10:51:46 PM
# 28  Time Series  4/6/2020 10:51:46 PM
# 46  Time Series  4/6/2020 10:51:46 PM
# 68  Time Series  4/6/2020 10:51:46 PM
# 73  Time Series  4/6/2020 10:51:46 PM

# %%
df.Country_Region.unique()
# Out:
# array(['Bahamas', 'Germany', 'Canada', 'Australia', 'Suriname', 'Estonia',
#        'Slovakia', 'Timor-Leste', 'China', 'Brazil', 'North Macedonia',
#        'Israel', 'Netherlands', 'Namibia', 'France', 'Mozambique',
#        'United Arab Emirates', 'Argentina', 'Honduras', 'Malta', 'Gabon',
#        'United Kingdom', 'Bulgaria', 'Singapore', 'New Zealand', 'Mexico',
#        'Panama', 'Ghana', 'Thailand', 'Costa Rica',
#        'Bosnia and Herzegovina', 'Korea, South', 'South Sudan', 'Gambia',
#        'Mali', 'Iran', 'Saint Vincent and the Grenadines', 'Tunisia',
#        'Algeria', 'Iraq', 'Nigeria', 'Albania', 'Sierra Leone', 'Liberia',
#        'Lebanon', 'Laos', 'Liechtenstein', 'Nicaragua', "Cote d'Ivoire",
#        'Holy See', 'Armenia', 'Georgia', 'Luxembourg', 'Haiti', 'Grenada',
#        'Czechia', 'Guyana', 'Taiwan*', 'Chad', 'Andorra', 'Afghanistan',
#        'Saint Kitts and Nevis', 'Uganda', 'Chile', 'Slovenia', 'Brunei',
#        'Oman', 'Paraguay', 'Romania', 'Belarus', 'Congo (Brazzaville)',
#        'Madagascar', 'Eritrea', 'Rwanda', 'Bahrain', 'Sweden', 'Senegal',
#        'Eswatini', 'Bolivia', 'Ireland', 'Saint Lucia', 'Mauritania',
#        'Togo', 'Bhutan', 'Finland', 'Belgium', 'Poland', 'Jordan',
#        'Denmark', 'Burkina Faso', 'Greece', 'Colombia', 'Austria',
#        'Kazakhstan', 'Cyprus', 'Zambia', 'El Salvador',
#        'Papua New Guinea', 'Egypt', 'Ecuador', 'Burma', 'Azerbaijan',
#        'Monaco', 'Ukraine', 'Qatar', 'Mauritius', 'Peru', 'Guinea',
#        'Moldova', 'Antigua and Barbuda', 'Kyrgyzstan', 'Cuba', 'Djibouti',
#        'Benin', 'Cambodia', 'Latvia', 'India', 'Malaysia', 'Syria',
#        'Russia', 'Fiji', 'Cruise Ship', 'Saudi Arabia', 'Portugal',
#        'Croatia', 'Pakistan', 'Dominica', 'Indonesia', 'Kenya',
#        'Philippines', 'San Marino', 'Uzbekistan', 'Tanzania', 'Lithuania',
#        'Japan', 'Switzerland', 'Montenegro', 'Guinea-Bissau', 'Niger',
#        'Guatemala', 'Zimbabwe', 'Hungary', 'Mongolia', 'Iceland',
#        'Barbados', 'Italy', 'Serbia', 'Sao Tome and Principe',
#        'Western Sahara', 'Equatorial Guinea', 'Uruguay', 'Cameroon',
#        'Nepal', 'Congo (Kinshasa)', 'Maldives', 'Vietnam', 'Bangladesh',
#        'Libya', 'Kuwait', 'Seychelles', 'Angola', 'Trinidad and Tobago',
#        'Sri Lanka', 'Morocco', 'Jamaica', 'Central African Republic',
#        'Botswana', 'West Bank and Gaza', 'Burundi', 'Belize', 'Venezuela',
#        'Sudan', 'Turkey', 'Norway', 'Somalia', 'Cabo Verde',
#        'Dominican Republic', 'Kosovo', 'Spain', 'South Africa', 'Malawi',
#        'Ethiopia', 'US'], dtype=object)

# %%
confirmed_df = canada_df[canada_df['Case_Type']=='Confirmed']
confirmed_df['Date'] = pd.to_datetime(confirmed_df['Date']);
confirmed_df.sort_values('Date', inplace = True);
confirmed_df[['Cases','Difference']].fillna(value = 0, inplace = True);



#confirmed_df = confirmed_df[['Cases','Date','Country_Region','Case_Type','Difference']].sort_values(by ='Date', ascending = True)
#confirmed_df.head()
# Out:
# C:\Users\codyl_000\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\codyl_000\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
confirmed_df['Difference'].min()
# Out:
# -7.0

# %%
confirmed_df[confirmed_df['Difference'] < 0]
# Out:
#       Case_Type  Cases  Difference       Date Country_Region Province_State  \
# 4820  Confirmed    358        -1.0 2020-03-25         Canada        Alberta
# 9961  Confirmed   4347        -7.0 2020-04-06         Canada        Ontario
#
#      Admin2 Combined_Key  FIPS      Lat      Long  Table_Names  \
# 4820    NaN          NaN   NaN  53.9333 -116.5765  Time Series
# 9961    NaN          NaN   NaN  51.2538  -85.3232  Time Series
#
#          Prep_Flow_Runtime
# 4820  4/6/2020 10:51:46 PM
# 9961  4/6/2020 10:51:46 PM

# %%
confirmed_df.head()
# Out:
#         Case_Type  Cases  Difference       Date Country_Region  \
# 523171  Confirmed      0         NaN 2020-01-22         Canada
# 478537  Confirmed      0         NaN 2020-01-22         Canada
# 481893  Confirmed      0         NaN 2020-01-22         Canada
# 481938  Confirmed      0         NaN 2020-01-22         Canada
# 481950  Confirmed      0         NaN 2020-01-22         Canada
#
#               Province_State Admin2 Combined_Key  FIPS      Lat      Long  \
# 523171               Alberta    NaN          NaN   NaN  53.9333 -116.5765
# 478537           Nova Scotia    NaN          NaN   NaN  44.6820  -63.7443
# 481893  Prince Edward Island    NaN          NaN   NaN  46.5107  -63.4168
# 481938               Ontario    NaN          NaN   NaN  51.2538  -85.3232
# 481950                Quebec    NaN          NaN   NaN  52.9399  -73.5491
#
#         Table_Names     Prep_Flow_Runtime
# 523171  Time Series  4/6/2020 10:51:46 PM
# 478537  Time Series  4/6/2020 10:51:46 PM
# 481893  Time Series  4/6/2020 10:51:46 PM
# 481938  Time Series  4/6/2020 10:51:46 PM
# 481950  Time Series  4/6/2020 10:51:46 PM

# %%
plt.figure(figsize = (10,10))
plt.bar(confirmed_df['Date'],confirmed_df['Difference'])
plt.ylabel('Number of Cases')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# Note that difference is the daily case and cases is the totol cases

# %%
### this is how to set intervels with matplotlib dates
### note that Y is a capital
sns.set_style('darkgrid')
x = confirmed_df.groupby('Date').sum()['Cases']
f, ax = plt.subplots(figsize = (10,10))
ax.bar(x.index.values, x, alpha = .5 )
ax.plot(x.index.values, x , '_')
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

# %%
df.Case_Type.unique()
# Out:
# array(['Deaths', 'Confirmed'], dtype=object)

# %%
df.sort_values('Date')
# Out:
#         Case_Type  Cases  Difference       Date Country_Region  \
# 404933     Deaths      1         0.0   4/6/2020             US
# 207075     Deaths      1         0.0   4/6/2020             US
# 459419     Deaths      9         0.0   4/6/2020             US
# 286082  Confirmed      0         0.0   4/6/2020             US
# 72561   Confirmed     37         0.0   4/6/2020             US
# 55379   Confirmed      2         1.0   4/6/2020             US
# 316728  Confirmed      9         2.0   4/6/2020             US
# 124653     Deaths      0         0.0   4/6/2020             US
# 452324  Confirmed      1         0.0   4/6/2020             US
# 377394  Confirmed      2         0.0   4/6/2020             US
# 236796     Deaths      1         0.0   4/6/2020             US
# 391540     Deaths      0         0.0   4/6/2020             US
# 170970  Confirmed      0         0.0   4/6/2020             US
# 405004     Deaths      1         0.0   4/6/2020             US
# 430056     Deaths      0         0.0   4/6/2020             US
# 48527   Confirmed      3         0.0   4/6/2020             US
# 101236  Confirmed     10         3.0   4/6/2020             US
# 441619  Confirmed     30         0.0   4/6/2020             US
# 27037   Confirmed     28         1.0   4/6/2020      Australia
# 356324     Deaths      3         0.0   4/6/2020             US
# 472249  Confirmed      6         0.0   4/6/2020             US
# 101162     Deaths      0         0.0   4/6/2020             US
# 529562  Confirmed    108         7.0   4/6/2020             US
# 331530     Deaths      0         0.0   4/6/2020             US
# 377468  Confirmed      7         2.0   4/6/2020             US
# 9169    Confirmed   1686        31.0   4/6/2020   South Africa
# 171017     Deaths      0         0.0   4/6/2020             US
# 254498     Deaths      0         0.0   4/6/2020             US
# 142295     Deaths      2         0.0   4/6/2020             US
# 171005     Deaths      0         0.0   4/6/2020             US
# ...           ...    ...         ...        ...            ...
# 501073     Deaths      0         NaN  1/22/2020             US
# 501074  Confirmed      0         NaN  1/22/2020             US
# 501075     Deaths      0         NaN  1/22/2020             US
# 501076  Confirmed      0         NaN  1/22/2020             US
# 501055  Confirmed      0         NaN  1/22/2020             US
# 501053     Deaths      0         NaN  1/22/2020             US
# 501030     Deaths      0         NaN  1/22/2020             US
# 501052  Confirmed      0         NaN  1/22/2020             US
# 501031     Deaths      0         NaN  1/22/2020             US
# 501032     Deaths      0         NaN  1/22/2020             US
# 501033  Confirmed      0         NaN  1/22/2020             US
# 501034     Deaths      0         NaN  1/22/2020             US
# 501035  Confirmed      0         NaN  1/22/2020             US
# 501036     Deaths      0         NaN  1/22/2020             US
# 501037     Deaths      0         NaN  1/22/2020             US
# 501038     Deaths      0         NaN  1/22/2020             US
# 501039     Deaths      0         NaN  1/22/2020             US
# 501040     Deaths      0         NaN  1/22/2020             US
# 501041  Confirmed      0         NaN  1/22/2020             US
# 501042  Confirmed      0         NaN  1/22/2020             US
# 501043  Confirmed      0         NaN  1/22/2020             US
# 501044  Confirmed      0         NaN  1/22/2020             US
# 501045     Deaths      0         NaN  1/22/2020             US
# 501046  Confirmed      0         NaN  1/22/2020             US
# 501047     Deaths      0         NaN  1/22/2020             US
# 501048  Confirmed      0         NaN  1/22/2020             US
# 501049     Deaths      0         NaN  1/22/2020             US
# 501050     Deaths      0         NaN  1/22/2020             US
# 501051  Confirmed      0         NaN  1/22/2020             US
# 533367     Deaths      0         NaN  1/22/2020             US
#
#             Province_State        Admin2                  Combined_Key  \
# 404933      North Carolina        Durham    Durham, North Carolina, US
# 207075             Georgia      Mitchell         Mitchell, Georgia, US
# 459419             Georgia       Clayton          Clayton, Georgia, US
# 286082              Kansas         Meade             Meade, Kansas, US
# 72561         Pennsylvania       Montour     Montour, Pennsylvania, US
# 55379                 Ohio        Holmes              Holmes, Ohio, US
# 316728        Pennsylvania      Crawford    Crawford, Pennsylvania, US
# 124653            Oklahoma        Blaine          Blaine, Oklahoma, US
# 452324               Idaho         Latah              Latah, Idaho, US
# 377394             Georgia         Heard            Heard, Georgia, US
